# %% [markdown]
# ## File Handling
#
# Reading and writing files are very common tasks that come in handy in programming. You can write a program to **read** data from files and also **write** computed results to files. This provides us with the basic infrastructure to process large amount of data in a few seconds.
#
# In this session we will deal with *text files*. They are files that only consists of lines of text without formatting information. For example, word documents or pages files are not *text files*, the formatting information contained in them can make handling them in a program more complicated.
#
#
# ### Reading Files
#
# To work with files in Python, you need to open the file first. The built-in `open()` function does what the name implies - it opens a file and returns it as a file object. So to use the `open()` function, you would need to save the returned value to a variable, so that you can access the opened file later.
#
# After the file is opened, you can use the `.read()` method to read content from it.
#
# Remember to always close the file with `.close()` method after you are done. Closing files on time helps to protect you from potential data loss. Also, an opened file prevents other processes from accessing the same file until your current program terminates.

# %%
# pure file name - within the same folder as the program
# ../ -> go outside of current folder
# folder_name/... ->  go inside a folder within the same level
my_file = open ("demofile.txt") # step 1: open
content = my_file.read() # step 2: read
print(content)
my_file.close() # step 3: close
# Out:
# ### Assignment 6
# The goal of this week is to build a small game based with an inventory management system to practice dictionary/list.
# You're a character exploring a (text-based) world, along the way, you can:
# - pick up and drop items
# - use or examine them
# - deal with inventory limits
#
# Core features
# 1. Inventory System
#   - A list holds your items: `inventory = []`
#   - Each item is a dictionary: `{"name": "medicine", "type": "healing", "uses": 1}`
#   - Inventory Limit: max of 5 items
# 2. Room System
#   - A list of dictionary represents items in the current area:
# ```
# items_in_room = [
#     {"name": "Key", "type": "tool"},
#     {"name": "Apple", "type": "food"}
# ]
# ```
# 3. Actions
#   - Use functions to define the following basic actions:
# ```
# def show_room_items(): ...
# def pick_up(item_name): ...
# def drop(item_name): ...
# def use(item_name): ...
# def show_inventory(): ...
# def examine(item_name): ...
# ```
# 4. User Interactions
#   - Users shall be able to navigate the game by typing commands in following ways
# ```
# inventory
# pickup apple
# drop torch
# use potion
# examine sword
# help
# ```
# 5. Define a meaningful scenario (goal and ending) for your little game. It could be a classic escape game, survival on an island, buying food in a supermarket...
#
# ** You can also integrate the system to what you have already built. Though that probably means more work on your side. If you are adding things on top of very long code, please clearly mark the sections where new changes are introduced for this week

# %% [markdown]
# Because we tend to be forgetful, it is recommended to open a file in combination with the `with` statement.
#
# In this way, the header line opens the file, and you can access the file only in the following block. After the block the file is automatically closed and you get to write less code.
#
# The following code cell does the same with the code above, but using `with` statement:

# %%
with open("demofile.txt") as file:
    content = file.read()
    print(content)
# here file is closed
# Out:
# Hello there!
# This example file contains three lines of text.
# This is the last line.

# %% [markdown]
# The method `read()` returns the contents of the entire file as a single string. When you use this function, Python will read the entire file into memory all at once. That can be a bad idea if you are working with a big file.
#
# Instead of reading the whole file all at once, what is used more often is to go through the file line by line. To achieve that we could iterate over the file using a for loop.

# %%
with open("demofile.txt") as f:
    for line in f:
        line = line.replace("\n", "") # remove line breaks from the file
        print(line)
# Out:
# Hello there!
# This example file contains three lines of text.
# This is the last line.

# %% [markdown]
# The `readline()` method returns one line from the file each time you call it. It automatically goes to the next line when you call it for the second time.

# %%
with open("demofile.txt") as f:
    print(f.readline())
    print(f.readline())
# Out:
# Hello there!
#
# This example file contains three lines of text.

# %% [markdown]
# In this way we can iterate over a file with a while loop. It is helpful to use `readline()` if we have a large file and we only need to read the first few lines in it.

# %%
with open("demofile.txt") as f:
    # Method 1 : for loop
    # for i in range(3):
    #     line = f.readline()
    #     print(line)

    # Method 2: while loop
    count = 0
    # loop over only the first three lines of a file
    while count < 3:
        line = f.readline()
        print(line)
        count += 1
# Out:
# Hello there!
#
# This example file contains three lines of text.
#
# This is the last line.

# %% [markdown]
# Another way is to use `readlines()`. It reads the whole file and returns the result as a list of lines. This is similar to `read()`, just return the text in a different format. So it's better to only use it on small files.

# %%
with open("demofile.txt") as f:
    for line in f.readlines():
        print(line)
# Out:
# Hello there!
#
# This example file contains three lines of text.
#
# This is the last line.

# %% [markdown]
# If the file is located in a different location, you will have to specify the file path, like this:

# %%
f = open("../test.txt") # either relative or absolute path
print(f.read())
# Out:
# this file exists outside of the week7 folder

# %% [markdown]
# #### Task1:
# Create/Locate a text file somewhere in your system and try to access it using what you have learnt above.

# %% [markdown]
# ---
# ### Writing Files
#
# The `open()` function has different modes. By default it is in read mode. That's why we can read a file without specifying the mode.

# %%
f1 = open("demofile.txt")
f1.close()

f2 = open("demofile.txt", "rt") # this is basically the same as the code above, r stands for read while t stands for text mode.  Another mode is b, binary mode (e.g. images)
f2.close()

# %% [markdown]
# To write to an existing file, we must add a parameter to the `open()` function:
#
# The `a` parameter will append the content to the end of the file.

# %%
# If you run this multiple times, the content gets longer
with open("demofile.txt", "a") as f:
  f.write("\nNow the file has more content!")

#open and read the file after the appending:
with open("demofile.txt") as f:
  print(f.read())
# Out:
# Hello there!
# This example file contains three lines of text.
# This is the last line.
# Now the file has more content!
# Now the file has more content!
# Now the file has more content!
# Now the file has more content!

# %% [markdown]
# Or to overwrite the existing content to the file, use the `w` parameter:

# %%
with open("demofile.txt", "w") as f:
  f.write("This text will overwrite the current text in the file.\n")
  f.write("It doesn't add line breaks automatically like print().\n")
  f.write("So you need to add line breaks manually by using \\n")

# %% [markdown]
# To create a new file in Python, you can use the `open()` method with one of the following parameters:
# - `x`: Create - will create a file, returns an error if the file exists
# - `a`: Append - will create a file if the specified file does not exist
# - `w`: Write - will create a file if the specified file does not exist

# %%
with open("new_new_file.txt", "a") as f:
  f.write("This will create a new file if the file doesn't exist yet. But also won't raise an error if it already exists.")

with open("new_file.txt") as f:
    print(f.read())
# Out:
# This will create a new file if the file doesn't exist yet. But also won't raise an error if it already exists.

# %% [markdown]
# ### Clearing and Delete Files

# %% [markdown]
# Sometimes it is necessary to clear the contents of an existing file. You can achieve it by opening the file in write mode and closing the file immediately:

# %%
open("demofile.txt", "w").close()

# Or another way to achieve the same thing
with open("demofile.txt", "w") as f:
    pass

# %% [markdown]
# To delete a file, you must import the OS module, and run its `os.remove()` function:

# %%
import os
os.remove("new_file.txt")

# %% [markdown]
# To avoid getting an error, you might want to check if the file exists before you try to delete it:

# %%
if os.path.exists("new_file.txt"):
  os.remove("new_file.txt")
else:
  print("The file does not exist")
# Out:
# The file does not exist

# %% [markdown]
# #### Task 2:
# Write a program that asks two inputs:
#  1. The name of the user (string)
#  2. How many weeks have you learned python (int)
#
# It shall create a `message.txt` file using the name of the user and generates the GitHub repo structure based on the number of weeks.
# The contents of your text file should look like this:
# ```
# Hi user_name, we hope you enjoy learning Python here!
# Your github repo should look like this:
#     assignments/
#         week1/
#         week2/
#         ...
#         week7/
#  ```

# %%
user_name = input("What's your name?")
week = int(input("How many weeks have you learned python?"))

with open("message.txt", "w") as f:
  f.write("Hi")

# %% [markdown]
# ---
# ### Exceptions Handling
#
# When an error occurs, or exception as we call it, Python will normally stop and generate an error message.

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# To prevent the program from crushing and raise an error we can put the code in question into the `try` block and handle the error with the `except` block.

# %%
try:
  print(x)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %% [markdown]
# Some common errors when working with files are **FileNotFoundError** (when trying to access a file which doesn't exist), **io.UnsupportedOperation** (when trying to perform an operation on a file which is not supported by the mode in which the file is opened) or **PermissionError** (the program lacks necessary permissions to access the file).
#
# These exceptions can be handled using the try/except statements:

# %%
try:
    with open("demofile2.txt") as my_file:
        for line in my_file:
            print(line)
except FileNotFoundError:
    print("The file demofile2.txt was not found")
# Out:
# The file demofile2.txt was not found

# %% [markdown]
# To go along with `try` and `except`, you can also use
#  - the `else` block to define a block of code to be executed if no errors were raised
#  - the `finally` block, if specified, will be executed regardless if the try block raises an error or not.

# %%
try:
  f = open("read_only.txt")
  try:
    f.write("Lorum Ipsum")
  except Exception as e:
      print(e)
  else:
    print("Successfully wrote to demofile.text.")
  finally:
    f.close() # This can be useful just to close the file
except PermissionError:
  print("Something went wrong when opening the file.")
# Out:
# not writable

# %% [markdown]
# You can also raise exceptions according to your own needs.

# %%
raise Exception("Sorry, this is a general exception")

# %% [markdown]
# Or raise very specific types of errors. This can be helpful when you are defining your own functions. You can use the error messages to guide others who are using your function.

# %%
def age(x):
    if type(x) is not int:
        raise TypeError("Only integers are allowed")
    if x < 0:
        raise ValueError("Sorry, age shall be larger than zero")
    return x

age(-1)

# %% [markdown]
# ---
# ### Dealing with CSVs

# %% [markdown]
# A CSV file, short for comma-separated Values, is a text file which contains data separated by a predetermined character. The most common characters used for this purpose are the commas `,` and the semicolons `;`, but in principle you can use any characters to separate the data.
#
# CSV files are commonly used to store records of different kinds. Many database and spreadsheet programs, such as Excel, can import and export data in CSV format, which makes data exchange between different systems easy.
#
# We already learnt we can go through the lines in a file with a for loop, but how can we separate the different fields on a single line?

# %%
with open("fruits.csv") as f:
    counter = 0
    for line in f:
        line = line.replace("\n", "")
        items = line.split(",")
        print(items[1])
        # how to access the price field for example?
        counter += 1
        if counter == 5:
            break
# Out:
# Price per kg
# 132.99
# 1.39
# 2.99
# 1.99

# %% [markdown]
# There is also a module dedicated to CSV so that we don't need to manually split each row.

# %%
import csv

# initializing the rows list
rows = []

# reading csv file
with open("fruits.csv") as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
    # extracting field names through first row, notice that it removes the first row at the same time from csvreader
    fields = next(csvreader)

    # printing the field names
    print('Field names are:', fields)

    # extracting each data row one by one, notice that the items are already separated for you
    for row in csvreader:
        rows.append(row)
        print(row)

    # get total number of rows
    print("Total no. of rows:", csvreader.line_num)
# Out:
# Field names are: ['Fruit', 'Price per kg', 'Origin']
# ['Apple', '132.99', 'Germany']
# ['Banana', '1.39', 'Ecuador']
# ['Orange', '2.99', 'Spain']
# ['Grapes', '1.99', 'Italy']
# ['Strawberry', '133.99', 'Germany']
# ['Kiwi', '2.50', 'New Zealand']
# ['Pineapple', '2.80', 'Costa Rica']
# ['Blueberry', '5.00', 'Spain']
# ['Pear', '2.20', 'Netherlands']
# ['Watermelon', '1.39', 'Spain']
# Total no. of rows: 11

# %% [markdown]
# We can print the rows in some nicely formatted ways. There are many ways to do it. Here we are showing one way of formatting using f string.
#
# In this example, note that each replacement field `{}` contains a string that starts with a colon `:`. That’s a format specifier. The `.10s` part tells Python that you want to format the value as a string (s) with the length of 10.

# %%
# printing first 3 rows
print('\nFirst 3 rows are:\n')
for row in rows[:3]:
    # parsing each column of a row
    for col in row:
        print(f"{col:10s}", end=" "), # start specify formatting with a colon :
    print('\n')
# Out:
# First 3 rows are:
#
# Apple      132.99     Germany
#
# Banana     1.39       Ecuador
#
# Orange     2.99       Spain

# %% [markdown]
# `DictReader` create an object that operates like a regular reader but maps the information in each row to a dict whose keys are given by the optional `fieldnames` parameter.

# %%
rows = []

with open('fruits.csv') as f:
    reader = csv.DictReader(f)
    fieldnames = reader.fieldnames
    print(fieldnames)
    for row in reader:
        print(row)
        rows.append(row)
# Out:
# ['Fruit', 'Price per kg', 'Origin']
# {'Fruit': 'Apple', 'Price per kg': '132.99', 'Origin': 'Germany'}
# {'Fruit': 'Banana', 'Price per kg': '1.39', 'Origin': 'Ecuador'}
# {'Fruit': 'Orange', 'Price per kg': '2.99', 'Origin': 'Spain'}
# {'Fruit': 'Grapes', 'Price per kg': '1.99', 'Origin': 'Italy'}
# {'Fruit': 'Strawberry', 'Price per kg': '133.99', 'Origin': 'Germany'}
# {'Fruit': 'Kiwi', 'Price per kg': '2.50', 'Origin': 'New Zealand'}
# {'Fruit': 'Pineapple', 'Price per kg': '2.80', 'Origin': 'Costa Rica'}
# {'Fruit': 'Blueberry', 'Price per kg': '5.00', 'Origin': 'Spain'}
# {'Fruit': 'Pear', 'Price per kg': '2.20', 'Origin': 'Netherlands'}
# {'Fruit': 'Watermelon', 'Price per kg': '1.39', 'Origin': 'Spain'}

# %% [markdown]
# In a dictionary format, we can access each single cell with more precision, and it can be very helpful if you want to do some fine processing of the data.

# %%
for row in rows:
    name = row["Fruit"]
    price = row["Price per kg"]
    origin = row["Origin"]
    print(f"{name:10s}", end=" ")
    # 5.2f specifies a floating-point number with two decimal places padded to a total width of 5 characters.
    print(f"{float(price):10.2f} ", end=" ")
    print(f"{origin}")
    print()
# Out:
# Apple          132.99  Germany
#
# Banana           1.39  Ecuador
#
# Orange           2.99  Spain
#
# Grapes           1.99  Italy
#
# Strawberry     133.99  Germany
#
# Kiwi             2.50  New Zealand
#
# Pineapple        2.80  Costa Rica
#
# Blueberry        5.00  Spain
#
# Pear             2.20  Netherlands
#
# Watermelon       1.39  Spain

# %% [markdown]
# But data are not always perfect clean and tidy. What if your data contains extra spaces or line breaks? Python's string method `strip()` will be very useful in this case. It removes all spaces, line breaks, tabs from the beginning and end of a string.

# %%
print(" tryout ".strip())
print("\ntryout   ".strip())
# Out:
# tryout
# tryout

# %% [markdown]
# There are multiple ways to write to a CSV file. One is to write to them as a normal text file.

# %%
with open('fruits.csv','a') as f:
    f.write("Cherry,5.99,Spain")

# %% [markdown]
# Or use `.writerow()` method from the CSV writer. Pay attention that it takes all the cells in a row as a list of strings.

# %%
import csv

with open("fruits.csv", "a") as file:
    writer = csv.writer(file)
    writer.writerow(["Mango","1.39","Spain"])

# %% [markdown]
# The third way is to use `DictWriter`. For both the normal writer and the `DictWriter` you can use `writerows()` to write multiple rows at one time.

# %%
with open('names.csv', 'w', newline='') as csvfile:
    fieldnames = ['first_name', 'last_name']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames) # specify fieldnames as a parameter
    writer.writeheader() # First writeheader() then writerow()
    writer.writerow({'first_name': 'Wonderful', 'last_name': 'Beans'})
    writer.writerows([{'first_name': 'Annoying', 'last_name': 'Spams'}, {'first_name': 'Lovely', 'last_name': 'Spams'}])
    #

# %% [markdown]
# #### Task 3:
# Add a new column "Available" to "fruits.csv" and populate the value with random `True/False` values
# - Hint: You need to first add the column header "Available" to first row, then appends the corresponding values to each row below.
# - You can use all three ways introduced above to do this task, but which way is better for what kind of scenario?
